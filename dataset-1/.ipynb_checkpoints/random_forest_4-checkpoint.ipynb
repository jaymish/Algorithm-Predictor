# %% [markdown]
# #### 12/8/2020
# ## COMP 541 - Assignment 6 - Team 6
# ### Table of Contents:
# * [1. Modeling Strategy and Initialization](#1)
# * &emsp;[1.1. Importing Libraries](#11)
# * &emsp;[1.2. Reading the Data & Splitting Traing and Test Datasets](#12)
# * &emsp;[1.3. Defining Modeling Functions](#13)
# * &emsp;[1.4. Defining K-Fold Cross Validation Splits](#14)
# * [2. Modeling](#2)
# * &emsp;[2.1. Classification Models](#21)
# * &emsp;&emsp;[2.1.1. K-Nearest Neighbors Classifier](#211)
# * &emsp;&emsp;&emsp;[2.1.1.1. Finding The Best Value of K](#2111)
# * &emsp;&emsp;&emsp;[2.1.1.2. Confusion Matrix (Validation)](#2112)
# * &emsp;&emsp;&emsp;[2.1.1.3. Confusion Matrix (Test)](#2113)
# * &emsp;&emsp;[2.1.2. Random Forest Classifier](#212)
# * &emsp;&emsp;&emsp;[2.1.2.1. Finding The Best Value of n_estimators](#2121)
# * &emsp;&emsp;&emsp;[2.1.2.2. Confusion Matrix (Validation)](#2122)
# * &emsp;&emsp;&emsp;[2.1.2.3. Confusion Matrix (Test)](#2123)
# * &emsp;&emsp;[2.1.3. Gradient Boosting Classifier](#213)
# * &emsp;&emsp;&emsp;[2.1.3.1. Finding The Best Value of n_estimators](#2131)
# * &emsp;&emsp;&emsp;[2.1.3.2. Confusion Matrix (Validation)](#2132)
# * &emsp;&emsp;&emsp;[2.1.3.3. Confusion Matrix (Test)](#2133)
# * &emsp;[2.2. Regression Models](#22)
# * &emsp;&emsp;[2.2.1. K-Nearest Neighbors Regressor](#221)
# * &emsp;&emsp;[2.2.2. Random Forest Regressor](#222)
# * &emsp;&emsp;[2.2.3. Gradient Boosting Regressor](#223)

# %% [markdown]
# # 1. Modeling Strategy and Initialization<a class="anchor" id="1"></a>

# %% [markdown]
# ## 1.1. Importing Libraries<a class="anchor" id="11"></a>

# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
import sklearn.metrics as metrics
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## 1.2. Reading the Data & Splitting Traing and Test Datasets<a class="anchor" id="12"></a>

# %%
df = pd.read_csv('data/final_training_data.csv')

# %%
clf_target = 'isprofit' # classification model target
reg_target = 'profitability_ratio' # regression model target
des_features = ['budget', 'budget_norm', 'genre', 'popularity', 'popularity_norm', 'rating', 'runtime',
                'runtime_norm', 'score', 'score_norm', 'votes', 'votes_norm', 'year'] # descriptive features

# %%
X = df[des_features] # training data is the same for classification model and regression model
y1 = df[clf_target] # y1 corresponds to binary label outcome that will be used in classification
y2 = df[reg_target] # y2 corresponds to continuous outcome that will be used in regression

X_train, X_test, y1_train, y1_test = train_test_split(X, y1, test_size=0.2, random_state=17)
X_train, X_test, y2_train, y2_test = train_test_split(X, y2, test_size=0.2, random_state=17)

X_train = X_train.reset_index(drop=True)
y1_train = pd.DataFrame(y1_train).reset_index(drop=True)
y2_train = pd.DataFrame(y2_train).reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y1_test = pd.DataFrame(y1_test).reset_index(drop=True)
y2_test = pd.DataFrame(y2_test).reset_index(drop=True)

# %% [markdown]
# ## 1.3. Defining Modeling Functions<a class="anchor" id="13"></a>

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    if not title:
        if normalize:
            pass
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm

# %%
def run_kfold_model(X,y,X_test,y_test,model,fold_indexes,folds=[1,2,3],model_name='Unknown'):
    results = {}
    for fold in folds:
        print('='*5+' '+model_name+' - fold '+str(fold)+' '+'='*5)
        x_train = X.loc[list(fold_indexes[fold]['train'])]
        x_valid = X.loc[list(fold_indexes[fold]['valid'])]
        y_train = y.loc[list(fold_indexes[fold]['train'])]
        y_valid = y.loc[list(fold_indexes[fold]['valid'])]
        print('fitting model...')
        start_time = time.time()
        model.fit(x_train, np.ravel(y_train))
        ex_time = (time.time() - start_time)
        print('model fit!')
        results[fold] = {}
        results[fold]['model'] = model
        results[fold]['preds'] = {
            'train_y_pred': model.predict(x_train),
            'train_y_prob': model.predict_proba(x_train)[:,1],
            'valid_y_pred': model.predict(x_valid),
            'valid_y_prob': model.predict_proba(x_valid)[:,1],
            'test_y_pred': model.predict(X_test),
            'test_y_prob': model.predict_proba(X_test)[:,1]
        }
        results[fold]['execution_time'] = ex_time
        # pprint.pprint(results[fold])
    return results

# %% [markdown]
# ## 1.4. Defining K-Fold Cross Validation Splits<a class="anchor" id="14"></a>

# %%
# This is where we create our folds
kf = KFold(n_splits=3, random_state=17, shuffle=True)
kf.get_n_splits(X_train)
fold_indexes = {}
i = 1
for train_index, valid_index in kf.split(X_train):
    fold_indexes[i]={}
    fold_indexes[i]['train']=train_index
    fold_indexes[i]['valid']=valid_index
    i+=1
    
y1_valid = np.ravel(y1_train.loc[list(fold_indexes[1]['valid'])+list(fold_indexes[2]['valid'])+list(fold_indexes[3]['valid'])])
y1_test = np.ravel(y1_test)

# %% [markdown]
# # 2. Modeling<a class="anchor" id="2"></a>

# %% [markdown]
# ## 2.1. Classification Models<a class="anchor" id="21"></a>

# %% [markdown]
# ### 2.1.1. K-Nearest Neighbor<a class="anchor" id="211"></a>

# %% [markdown]
# #### 2.1.1.1. Finding The Best Value of K<a class="anchor" id="2111"></a>

# %%
error = []

# Calculating error for K values between 1 and 40
for i in range(1, 40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y1_train.values.ravel())
    pred_i = knn.predict(X_test)
    error.append(np.mean(pred_i != y1_test))

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(1, 40), error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('K-Nearest Neighbors Classifier - Error Rate with K Value');
plt.xlabel('K Value');
plt.ylabel('Mean Error');

# %% [markdown]
# The best suitable value of K is 5, as it has the lowest mean error.

# %% [markdown]
# #### 2.1.1.2. Confusion Matrix (Validation)<a class="anchor" id="2112"></a>

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn_results = run_kfold_model(X_train,y1_train,X_test,y1_test,knn,fold_indexes,model_name='KNN Classification')
# Out:
# ===== KNN Classification - fold 1 =====
# fitting model...
# model fit!
# ===== KNN Classification - fold 2 =====
# fitting model...
# model fit!
# ===== KNN Classification - fold 3 =====
# fitting model...
# model fit!

# %%
valid_pred = list(knn_results[1]['preds']['valid_y_pred'])+\
             list(knn_results[2]['preds']['valid_y_pred'])+\
             list(knn_results[3]['preds']['valid_y_pred'])

# %%
cm = plot_confusion_matrix(y1_valid,valid_pred,classes=[0,1],title='KNN Confusion matrix (Validation)')
plt.show()

# %%
TP, TN, FP, FN = cm[1,1], cm[0,0], cm[0,1], cm[1,0]
TPR = TP/(TP+FN) # Sensitivity, hit rate, recall, or true positive rate
TNR = TN/(TN+FP) # Specificity or true negative rate
PPV = TP/(TP+FP) # Precision or positive predictive value
F1S = 2*TPR*PPV/(TPR+PPV) # F-1 score
ACC = (TP+TN)/(TP+FP+FN+TN) # Overall accuracy
print('Accuracy   : %.3f' % ACC, " (Overall, how often is the classifier correct?)")
print('Sensitivity: %.3f' % TPR, " (When it's actually yes, how often does it predict yes?)")
print('Specificity: %.3f' % TNR, " (When it's actually no, how often does it predict no?)")
print('Precision  : %.3f' % PPV, " (When it predicts yes, how often is it correct??)")
print('F-1 Score  : %.3f' % F1S, " (Harmonic average of Sensitivity and Precision)")
# Out:
# Accuracy   : 0.605  (Overall, how often is the classifier correct?)
# Sensitivity: 0.507  (When it's actually yes, how often does it predict yes?)
# Specificity: 0.686  (When it's actually no, how often does it predict no?)
# Precision  : 0.568  (When it predicts yes, how often is it correct??)
# F-1 Score  : 0.536  (Harmonic average of Sensitivity and Precision)

# %% [markdown]
# #### 2.1.1.3. Confusion Matrix (Test)<a class="anchor" id="2113"></a>

# %%
threshold = 0.5
test_probs = knn_results[1]['preds']['test_y_prob']+\
             knn_results[2]['preds']['test_y_prob']+\
             knn_results[3]['preds']['test_y_prob']
test_probs /= 3
test_pred = (test_probs>=threshold).astype(int)

# %%
cm = plot_confusion_matrix(y1_test,test_pred,classes=[0,1],title='KNN Confusion matrix (Test)')
plt.show()

# %%
TP, TN, FP, FN = cm[1,1], cm[0,0], cm[0,1], cm[1,0]
TPR = TP/(TP+FN) # Sensitivity, hit rate, recall, or true positive rate
TNR = TN/(TN+FP) # Specificity or true negative rate
PPV = TP/(TP+FP) # Precision or positive predictive value
F1S = 2*TPR*PPV/(TPR+PPV) # F-1 score
ACC = (TP+TN)/(TP+FP+FN+TN) # Overall accuracy
print('Accuracy   : %.3f' % ACC, " (Overall, how often is the classifier correct?)")
print('Sensitivity: %.3f' % TPR, " (When it's actually yes, how often does it predict yes?)")
print('Specificity: %.3f' % TNR, " (When it's actually no, how often does it predict no?)")
print('Precision  : %.3f' % PPV, " (When it predicts yes, how often is it correct??)")
print('F-1 Score  : %.3f' % F1S, " (Harmonic average of Sensitivity and Precision)")
# Out:
# Accuracy   : 0.604  (Overall, how often is the classifier correct?)
# Sensitivity: 0.493  (When it's actually yes, how often does it predict yes?)
# Specificity: 0.722  (When it's actually no, how often does it predict no?)
# Precision  : 0.652  (When it predicts yes, how often is it correct??)
# F-1 Score  : 0.561  (Harmonic average of Sensitivity and Precision)

# %% [markdown]
# ### 2.1.2. Random Forest Classifier<a class="anchor" id="212"></a>

# %% [markdown]
# #### 2.1.2.1. Finding The Best Value of n_estimators<a class="anchor" id="2121"></a>

# %%
error = []
n_estimators = list(range(1,16))
for n_estimator in n_estimators:
    rf = RandomForestClassifier(n_estimators=n_estimator,min_samples_split=60, min_samples_leaf=20,
                                max_depth=7, random_state=17, max_features=None, verbose=0, max_leaf_nodes=14)
    rf.fit(X_train, y1_train.values.ravel())
    pred_i = rf.predict(X_test)
    error.append(np.mean(pred_i != y1_test))

# %%
plt.figure(figsize=(12, 6))
plt.plot(n_estimators, error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Random Forest Classifier - Error Rate with N Estimators');
plt.xlabel('n_estimators');
plt.ylabel('Mean Error');

# %% [markdown]
# Minimum error rate at n_estimators = 8

# %% [markdown]
# #### 2.1.2.2. Confusion Matrix (Validation)<a class="anchor" id="2122"></a>

# %%
rf = RandomForestClassifier(n_estimators=8,min_samples_split=60, min_samples_leaf=20,
                                max_depth=7, random_state=17, max_features=None, verbose=0, max_leaf_nodes=14)
rf_results = run_kfold_model(X_train,y1_train,X_test,y1_test,rf,fold_indexes,model_name='RF Classification')
# Out:
# ===== RF Classification - fold 1 =====
# fitting model...
# model fit!
# ===== RF Classification - fold 2 =====
# fitting model...
# model fit!
# ===== RF Classification - fold 3 =====
# fitting model...
# model fit!

# %%
valid_pred = list(rf_results[1]['preds']['valid_y_pred'])+\
             list(rf_results[2]['preds']['valid_y_pred'])+\
             list(rf_results[3]['preds']['valid_y_pred'])

# %%
cm = plot_confusion_matrix(y1_valid,valid_pred,classes=[0,1],title='RF Confusion matrix (Validation)')
plt.show()

# %%
TP, TN, FP, FN = cm[1,1], cm[0,0], cm[0,1], cm[1,0]
TPR = TP/(TP+FN) # Sensitivity, hit rate, recall, or true positive rate
TNR = TN/(TN+FP) # Specificity or true negative rate
PPV = TP/(TP+FP) # Precision or positive predictive value
F1S = 2*TPR*PPV/(TPR+PPV) # F-1 score
ACC = (TP+TN)/(TP+FP+FN+TN) # Overall accuracy
print('Accuracy   : %.3f' % ACC, " (Overall, how often is the classifier correct?)")
print('Sensitivity: %.3f' % TPR, " (When it's actually yes, how often does it predict yes?)")
print('Specificity: %.3f' % TNR, " (When it's actually no, how often does it predict no?)")
print('Precision  : %.3f' % PPV, " (When it predicts yes, how often is it correct??)")
print('F-1 Score  : %.3f' % F1S, " (Harmonic average of Sensitivity and Precision)")
# Out:
# Accuracy   : 0.684  (Overall, how often is the classifier correct?)
# Sensitivity: 0.588  (When it's actually yes, how often does it predict yes?)
# Specificity: 0.762  (When it's actually no, how often does it predict no?)
# Precision  : 0.668  (When it predicts yes, how often is it correct??)
# F-1 Score  : 0.626  (Harmonic average of Sensitivity and Precision)

# %% [markdown]
# #### 2.1.2.3. Confusion Matrix (Test)<a class="anchor" id="2123"></a>

# %%
threshold = 0.5
test_probs = rf_results[1]['preds']['test_y_prob']+\
             rf_results[2]['preds']['test_y_prob']+\
             rf_results[3]['preds']['test_y_prob']
test_probs /= 3
test_pred = (test_probs>=threshold).astype(int)

# %%
cm = plot_confusion_matrix(y1_test,pred_i,classes=[0,1],title='RF Confusion matrix (Test)')
plt.show()

# %%
TP, TN, FP, FN = cm[1,1], cm[0,0], cm[0,1], cm[1,0]
TPR = TP/(TP+FN) # Sensitivity, hit rate, recall, or true positive rate
TNR = TN/(TN+FP) # Specificity or true negative rate
PPV = TP/(TP+FP) # Precision or positive predictive value
F1S = 2*TPR*PPV/(TPR+PPV) # F-1 score
ACC = (TP+TN)/(TP+FP+FN+TN) # Overall accuracy
print('Accuracy   : %.3f' % ACC, " (Overall, how often is the classifier correct?)")
print('Sensitivity: %.3f' % TPR, " (When it's actually yes, how often does it predict yes?)")
print('Specificity: %.3f' % TNR, " (When it's actually no, how often does it predict no?)")
print('Precision  : %.3f' % PPV, " (When it predicts yes, how often is it correct??)")
print('F-1 Score  : %.3f' % F1S, " (Harmonic average of Sensitivity and Precision)")
# Out:
# Accuracy   : 0.669  (Overall, how often is the classifier correct?)
# Sensitivity: 0.610  (When it's actually yes, how often does it predict yes?)
# Specificity: 0.732  (When it's actually no, how often does it predict no?)
# Precision  : 0.706  (When it predicts yes, how often is it correct??)
# F-1 Score  : 0.654  (Harmonic average of Sensitivity and Precision)

# %% [markdown]
# ### 2.1.3. Gradient Boosting Classifier<a class="anchor" id="213"></a>

# %% [markdown]
# #### 2.1.3.1. Finding The Best Value of n_estimators<a class="anchor" id="2131"></a>

# %%
error = []
n_estimators = [e*100 for e in list(range(1,16))]
for n_estimator in n_estimators:
    gb = GradientBoostingClassifier(learning_rate=0.001, n_estimators=n_estimator, criterion='friedman_mse', 
                                    min_samples_split=60, min_samples_leaf=20, max_depth=7, random_state=17,
                                    max_features=None, verbose=0, max_leaf_nodes=14, tol=0.0001)
    gb.fit(X_train, y1_train.values.ravel())
    pred_i = gb.predict(X_test)
    error.append(np.mean(pred_i != y1_test))

# %%
plt.figure(figsize=(12, 6))
plt.plot(n_estimators, error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Gradient Boosting Classifier - Error Rate with N Estimators');
plt.xlabel('n_estimators');
plt.ylabel('Mean Error');

# %% [markdown]
# The change in error rate is negligible after n_estimators >= 1000. Thus, we select n_estimators=1000

# %% [markdown]
# #### 2.1.3.2. Confusion Matrix (Validation)<a class="anchor" id="2132"></a>

# %%
gb = GradientBoostingClassifier(learning_rate=0.001, n_estimators=1000, criterion='friedman_mse', 
                                min_samples_split=60, min_samples_leaf=20, max_depth=7, random_state=17,
                                max_features=None, verbose=0, max_leaf_nodes=14, tol=0.0001)
gb_results = run_kfold_model(X_train,y1_train,X_test,y1_test,gb,fold_indexes,model_name='GB Classification')
# Out:
# ===== GB Classification - fold 1 =====
# fitting model...
# model fit!
# ===== GB Classification - fold 2 =====
# fitting model...
# model fit!
# ===== GB Classification - fold 3 =====
# fitting model...
# model fit!

# %%
valid_pred = list(gb_results[1]['preds']['valid_y_pred'])+\
             list(gb_results[2]['preds']['valid_y_pred'])+\
             list(gb_results[3]['preds']['valid_y_pred'])

# %%
cm = plot_confusion_matrix(y1_valid,valid_pred,classes=[0,1],title='GB Confusion matrix (Validation)')
plt.show()

# %%
TP, TN, FP, FN = cm[1,1], cm[0,0], cm[0,1], cm[1,0]
TPR = TP/(TP+FN) # Sensitivity, hit rate, recall, or true positive rate
TNR = TN/(TN+FP) # Specificity or true negative rate
PPV = TP/(TP+FP) # Precision or positive predictive value
F1S = 2*TPR*PPV/(TPR+PPV) # F-1 score
ACC = (TP+TN)/(TP+FP+FN+TN) # Overall accuracy
print('Accuracy   : %.3f' % ACC, " (Overall, how often is the classifier correct?)")
print('Sensitivity: %.3f' % TPR, " (When it's actually yes, how often does it predict yes?)")
print('Specificity: %.3f' % TNR, " (When it's actually no, how often does it predict no?)")
print('Precision  : %.3f' % PPV, " (When it predicts yes, how often is it correct??)")
print('F-1 Score  : %.3f' % F1S, " (Harmonic average of Sensitivity and Precision)")
# Out:
# Accuracy   : 0.693  (Overall, how often is the classifier correct?)
# Sensitivity: 0.560  (When it's actually yes, how often does it predict yes?)
# Specificity: 0.802  (When it's actually no, how often does it predict no?)
# Precision  : 0.697  (When it predicts yes, how often is it correct??)
# F-1 Score  : 0.621  (Harmonic average of Sensitivity and Precision)

# %% [markdown]
# #### 2.1.3.3. Confusion Matrix (Test)<a class="anchor" id="2133"></a>

# %%
threshold = 0.5
test_probs = gb_results[1]['preds']['test_y_prob']+\
             gb_results[2]['preds']['test_y_prob']+\
             gb_results[3]['preds']['test_y_prob']
test_probs /= 3
test_pred = (test_probs>=threshold).astype(int)

# %%
cm = plot_confusion_matrix(y1_test,pred_i,classes=[0,1],title='GB Confusion matrix (Test)')
plt.show()

# %%
TP, TN, FP, FN = cm[1,1], cm[0,0], cm[0,1], cm[1,0]
TPR = TP/(TP+FN) # Sensitivity, hit rate, recall, or true positive rate
TNR = TN/(TN+FP) # Specificity or true negative rate
PPV = TP/(TP+FP) # Precision or positive predictive value
F1S = 2*TPR*PPV/(TPR+PPV) # F-1 score
ACC = (TP+TN)/(TP+FP+FN+TN) # Overall accuracy
print('Accuracy   : %.3f' % ACC, " (Overall, how often is the classifier correct?)")
print('Sensitivity: %.3f' % TPR, " (When it's actually yes, how often does it predict yes?)")
print('Specificity: %.3f' % TNR, " (When it's actually no, how often does it predict no?)")
print('Precision  : %.3f' % PPV, " (When it predicts yes, how often is it correct??)")
print('F-1 Score  : %.3f' % F1S, " (Harmonic average of Sensitivity and Precision)")
# Out:
# Accuracy   : 0.684  (Overall, how often is the classifier correct?)
# Sensitivity: 0.605  (When it's actually yes, how often does it predict yes?)
# Specificity: 0.768  (When it's actually no, how often does it predict no?)
# Precision  : 0.734  (When it predicts yes, how often is it correct??)
# F-1 Score  : 0.663  (Harmonic average of Sensitivity and Precision)

# %% [markdown]
# ## 2.2. Regression Models<a class="anchor" id="22"></a>

# %% [markdown]
# ### 2.2.1. KNN Regressor<a class="anchor" id="221"></a>

# %%
knn_results_lst = []
k_neighbors_lst = list(range(2,21))
for k in k_neighbors_lst:
    # build model
    knn = KNeighborsRegressor(n_neighbors = k)
    knn.fit(X_train, y2_train)
    # train set metrics
    knn_medianAbsoluteError_train = metrics.median_absolute_error(y2_train, knn.predict(X_train))
    knn_meanAbsoluteError_train = metrics.mean_absolute_error(y2_train, knn.predict(X_train))
    knn_RMSE_train = np.sqrt(metrics.mean_squared_error(y2_train, knn.predict(X_train)))
    # test set metrics
    knn_medianAbsoluteError_test = metrics.median_absolute_error(y2_test, knn.predict(X_test))
    knn_meanAbsoluteError_test = metrics.mean_absolute_error(y2_test, knn.predict(X_test))
    knn_RMSE_test = np.sqrt(metrics.mean_squared_error(y2_test, knn.predict(X_test)))
    # print results
    print("k = %2d [TRAIN]" % k, end=" >> ")
    print ("median_abs_err = %.3f" % knn_medianAbsoluteError_train, end=", ")
    print ("mean_abs_err = %.3f" % knn_meanAbsoluteError_train, end=", ")
    print ("RMSE = %.3f" % knn_RMSE_train)
    print("k = %2d [TEST ]" % k, end=" >> ")
    print ("median_abs_err = %.3f" % knn_medianAbsoluteError_test, end=", ")
    print ("mean_abs_err = %.3f" % knn_meanAbsoluteError_test, end=", ")
    print ("RMSE = %.3f" % knn_RMSE_test)
    knn_results_lst.append((k, knn_medianAbsoluteError_train, knn_meanAbsoluteError_train, knn_RMSE_train, 'train'))
    knn_results_lst.append((k, knn_medianAbsoluteError_test, knn_meanAbsoluteError_test, knn_RMSE_test, 'test'))
# Out:
# k =  2 [TRAIN] >> median_abs_err = 0.309, mean_abs_err = 0.450, RMSE = 0.628
# k =  2 [TEST ] >> median_abs_err = 0.650, mean_abs_err = 0.882, RMSE = 1.199
# k =  3 [TRAIN] >> median_abs_err = 0.394, mean_abs_err = 0.535, RMSE = 0.726
# k =  3 [TEST ] >> median_abs_err = 0.661, mean_abs_err = 0.828, RMSE = 1.105
# k =  4 [TRAIN] >> median_abs_err = 0.431, mean_abs_err = 0.578, RMSE = 0.777
# k =  4 [TEST ] >> median_abs_err = 0.584, mean_abs_err = 0.794, RMSE = 1.063
# k =  5 [TRAIN] >> median_abs_err = 0.433, mean_abs_err = 0.598, RMSE = 0.804
# k =  5 [TEST ] >> median_abs_err = 0.592, mean_abs_err = 0.766, RMSE = 1.024
# k =  6 [TRAIN] >> median_abs_err = 0.452, mean_abs_err = 0.608, RMSE = 0.816
# k =  6 [TEST ] >> median_abs_err = 0.589, mean_abs_err = 0.758, RMSE = 1.013
# k =  7 [TRAIN] >> median_abs_err = 0.461, mean_abs_err = 0.617, RMSE = 0.823
# k =  7 [TEST ] >> median_abs_err = 0.609, mean_abs_err = 0.754, RMSE = 1.001
# k =  8 [TRAIN] >> median_abs_err = 0.468, mean_abs_err = 0.623, RMSE = 0.834
# k =  8 [TEST ] >> median_abs_err = 0.574, mean_abs_err = 0.746, RMSE = 0.993
# k =  9 [TRAIN] >> median_abs_err = 0.477, mean_abs_err = 0.634, RMSE = 0.847
# k =  9 [TEST ] >> median_abs_err = 0.589, mean_abs_err = 0.742, RMSE = 0.986
# k = 10 [TRAIN] >> median_abs_err = 0.491, mean_abs_err = 0.646, RMSE = 0.859
# k = 10 [TEST ] >> median_abs_err = 0.605, mean_abs_err = 0.740, RMSE = 0.976
# k = 11 [TRAIN] >> median_abs_err = 0.502, mean_abs_err = 0.651, RMSE = 0.863
# k = 11 [TEST ] >> median_abs_err = 0.587, mean_abs_err = 0.742, RMSE = 0.977
# k = 12 [TRAIN] >> median_abs_err = 0.504, mean_abs_err = 0.656, RMSE = 0.869
# k = 12 [TEST ] >> median_abs_err = 0.588, mean_abs_err = 0.740, RMSE = 0.977
# k = 13 [TRAIN] >> median_abs_err = 0.504, mean_abs_err = 0.659, RMSE = 0.874
# k = 13 [TEST ] >> median_abs_err = 0.600, mean_abs_err = 0.742, RMSE = 0.980
# k = 14 [TRAIN] >> median_abs_err = 0.510, mean_abs_err = 0.663, RMSE = 0.879
# k = 14 [TEST ] >> median_abs_err = 0.607, mean_abs_err = 0.740, RMSE = 0.978
# k = 15 [TRAIN] >> median_abs_err = 0.519, mean_abs_err = 0.665, RMSE = 0.882
# k = 15 [TEST ] >> median_abs_err = 0.592, mean_abs_err = 0.739, RMSE = 0.976
# k = 16 [TRAIN] >> median_abs_err = 0.515, mean_abs_err = 0.668, RMSE = 0.885
# k = 16 [TEST ] >> median_abs_err = 0.578, mean_abs_err = 0.738, RMSE = 0.978
# k = 17 [TRAIN] >> median_abs_err = 0.537, mean_abs_err = 0.673, RMSE = 0.888
# k = 17 [TEST ] >> median_abs_err = 0.602, mean_abs_err = 0.743, RMSE = 0.979
# k = 18 [TRAIN] >> median_abs_err = 0.546, mean_abs_err = 0.678, RMSE = 0.890
# k = 18 [TEST ] >> median_abs_err = 0.597, mean_abs_err = 0.742, RMSE = 0.974
# k = 19 [TRAIN] >> median_abs_err = 0.549, mean_abs_err = 0.681, RMSE = 0.891
# k = 19 [TEST ] >> median_abs_err = 0.605, mean_abs_err = 0.744, RMSE = 0.977
# k = 20 [TRAIN] >> median_abs_err = 0.550, mean_abs_err = 0.683, RMSE = 0.894
# k = 20 [TEST ] >> median_abs_err = 0.611, mean_abs_err = 0.747, RMSE = 0.980

# %%
knn_regression_results=pd.DataFrame(knn_results_lst,\
columns=['n_neighbors','median_abs_err','mean_abs_err','RMSE','dataset'])

# %%
plt.figure(figsize=(10, 5))
fig = sns.lineplot(data=knn_regression_results,x='n_neighbors',y='RMSE',hue='dataset')
fig.set_xticks(k_neighbors_lst);
fig.set_xticklabels(k_neighbors_lst);
fig.set_title('Change in RMSE in increasing Neighbors (KNN Regressor)');

# %% [markdown]
# ### 2.2.2. Random Forest Regressor<a class="anchor" id="222"></a>

# %%
rf_results_lst = []
n_estimators = [e for e in list(range(1,16))]
for k in n_estimators:
    # build model
    rf = RandomForestRegressor(n_estimators=k, criterion='friedman_mse', 
                                min_samples_split=100, min_samples_leaf=30, max_depth=7, random_state=17,
                                max_features=None, verbose=0, max_leaf_nodes=14)
    rf.fit(X_train, np.ravel(y2_train))
    # train set metrics
    rf_medianAbsoluteError_train = metrics.median_absolute_error(y2_train, rf.predict(X_train))
    rf_meanAbsoluteError_train = metrics.mean_absolute_error(y2_train, rf.predict(X_train))
    rf_RMSE_train = np.sqrt(metrics.mean_squared_error(y2_train, rf.predict(X_train)))
    # test set metrics
    rf_medianAbsoluteError_test = metrics.median_absolute_error(y2_test, rf.predict(X_test))
    rf_meanAbsoluteError_test = metrics.mean_absolute_error(y2_test, rf.predict(X_test))
    rf_RMSE_test = np.sqrt(metrics.mean_squared_error(y2_test, rf.predict(X_test)))
    # print results
    print("n_estimators = %2d [TRAIN]" % k, end=" >> ")
    print ("median_abs_err = %.3f" % rf_medianAbsoluteError_train, end=", ")
    print ("mean_abs_err = %.3f" % rf_meanAbsoluteError_train, end=", ")
    print ("RMSE = %.3f" % rf_RMSE_train)
    print("n_estimators = %2d [TEST ]" % k, end=" >> ")
    print ("median_abs_err = %.3f" % rf_medianAbsoluteError_test, end=", ")
    print ("mean_abs_err = %.3f" % rf_meanAbsoluteError_test, end=", ")
    print ("RMSE = %.3f" % rf_RMSE_test)
    rf_results_lst.append((k, rf_medianAbsoluteError_train, rf_meanAbsoluteError_train, rf_RMSE_train, 'train'))
    rf_results_lst.append((k, rf_medianAbsoluteError_test, rf_meanAbsoluteError_test, rf_RMSE_test, 'test'))
# Out:
# n_estimators =  1 [TRAIN] >> median_abs_err = 0.485, mean_abs_err = 0.645, RMSE = 0.859
# n_estimators =  1 [TEST ] >> median_abs_err = 0.541, mean_abs_err = 0.711, RMSE = 0.948
# n_estimators =  2 [TRAIN] >> median_abs_err = 0.476, mean_abs_err = 0.618, RMSE = 0.821
# n_estimators =  2 [TEST ] >> median_abs_err = 0.538, mean_abs_err = 0.688, RMSE = 0.915
# n_estimators =  3 [TRAIN] >> median_abs_err = 0.464, mean_abs_err = 0.615, RMSE = 0.819
# n_estimators =  3 [TEST ] >> median_abs_err = 0.523, mean_abs_err = 0.685, RMSE = 0.921
# n_estimators =  4 [TRAIN] >> median_abs_err = 0.459, mean_abs_err = 0.613, RMSE = 0.818
# n_estimators =  4 [TEST ] >> median_abs_err = 0.523, mean_abs_err = 0.680, RMSE = 0.920
# n_estimators =  5 [TRAIN] >> median_abs_err = 0.462, mean_abs_err = 0.611, RMSE = 0.816
# n_estimators =  5 [TEST ] >> median_abs_err = 0.508, mean_abs_err = 0.679, RMSE = 0.918
# n_estimators =  6 [TRAIN] >> median_abs_err = 0.479, mean_abs_err = 0.612, RMSE = 0.815
# n_estimators =  6 [TEST ] >> median_abs_err = 0.510, mean_abs_err = 0.677, RMSE = 0.913
# n_estimators =  7 [TRAIN] >> median_abs_err = 0.482, mean_abs_err = 0.609, RMSE = 0.809
# n_estimators =  7 [TEST ] >> median_abs_err = 0.529, mean_abs_err = 0.674, RMSE = 0.909
# n_estimators =  8 [TRAIN] >> median_abs_err = 0.476, mean_abs_err = 0.607, RMSE = 0.808
# n_estimators =  8 [TEST ] >> median_abs_err = 0.514, mean_abs_err = 0.671, RMSE = 0.906
# n_estimators =  9 [TRAIN] >> median_abs_err = 0.475, mean_abs_err = 0.605, RMSE = 0.805
# n_estimators =  9 [TEST ] >> median_abs_err = 0.515, mean_abs_err = 0.671, RMSE = 0.903
# n_estimators = 10 [TRAIN] >> median_abs_err = 0.471, mean_abs_err = 0.605, RMSE = 0.804
# n_estimators = 10 [TEST ] >> median_abs_err = 0.518, mean_abs_err = 0.668, RMSE = 0.898
# n_estimators = 11 [TRAIN] >> median_abs_err = 0.470, mean_abs_err = 0.604, RMSE = 0.805
# n_estimators = 11 [TEST ] >> median_abs_err = 0.520, mean_abs_err = 0.664, RMSE = 0.896
# n_estimators = 12 [TRAIN] >> median_abs_err = 0.473, mean_abs_err = 0.603, RMSE = 0.803
# n_estimators = 12 [TEST ] >> median_abs_err = 0.516, mean_abs_err = 0.666, RMSE = 0.897
# n_estimators = 13 [TRAIN] >> median_abs_err = 0.477, mean_abs_err = 0.604, RMSE = 0.803
# n_estimators = 13 [TEST ] >> median_abs_err = 0.528, mean_abs_err = 0.668, RMSE = 0.899
# n_estimators = 14 [TRAIN] >> median_abs_err = 0.475, mean_abs_err = 0.604, RMSE = 0.803
# n_estimators = 14 [TEST ] >> median_abs_err = 0.524, mean_abs_err = 0.667, RMSE = 0.896
# n_estimators = 15 [TRAIN] >> median_abs_err = 0.474, mean_abs_err = 0.605, RMSE = 0.803
# n_estimators = 15 [TEST ] >> median_abs_err = 0.528, mean_abs_err = 0.667, RMSE = 0.896

# %%
rf_regression_results=pd.DataFrame(rf_results_lst,\
columns=['n_neighbors','median_abs_err','mean_abs_err','RMSE','dataset'])

# %%
plt.figure(figsize=(10, 5))
fig = sns.lineplot(data=rf_regression_results,x='n_neighbors',y='RMSE',hue='dataset')
fig.set_xticks(n_estimators);
fig.set_xticklabels(n_estimators);
fig.set_title('Change in RMSE in increasing Neighbors (RF Regressor)');

# %% [markdown]
# ## 2.2.3. Gradient Boosting Regressor<a class="anchor" id="223"></a>

# %%
gb_results_lst = []
n_estimators = [e*100 for e in list(range(1,16))]
for k in n_estimators:
    # build model
    gb = GradientBoostingRegressor(learning_rate=0.0015, n_estimators=k, criterion='friedman_mse', 
                                min_samples_split=30, min_samples_leaf=10, max_depth=7, random_state=17,
                                max_features=None, verbose=0, max_leaf_nodes=25)
    gb.fit(X_train, np.ravel(y2_train))
    # train set metrics
    gb_medianAbsoluteError_train = metrics.median_absolute_error(y2_train, gb.predict(X_train))
    gb_meanAbsoluteError_train = metrics.mean_absolute_error(y2_train, gb.predict(X_train))
    gb_RMSE_train = np.sqrt(metrics.mean_squared_error(y2_train, gb.predict(X_train)))
    # test set metrics
    gb_medianAbsoluteError_test = metrics.median_absolute_error(y2_test, gb.predict(X_test))
    gb_meanAbsoluteError_test = metrics.mean_absolute_error(y2_test, gb.predict(X_test))
    gb_RMSE_test = np.sqrt(metrics.mean_squared_error(y2_test, gb.predict(X_test)))
    # print results
    print("n_estimators = %2d [TRAIN]" % k, end=" >> ")
    print ("median_abs_err = %.3f" % gb_medianAbsoluteError_train, end=", ")
    print ("mean_abs_err = %.3f" % gb_meanAbsoluteError_train, end=", ")
    print ("RMSE = %.3f" % gb_RMSE_train)
    print("n_estimators = %2d [TEST ]" % k, end=" >> ")
    print ("median_abs_err = %.3f" % gb_medianAbsoluteError_test, end=", ")
    print ("mean_abs_err = %.3f" % gb_meanAbsoluteError_test, end=", ")
    print ("RMSE = %.3f" % gb_RMSE_test)
    gb_results_lst.append((k, gb_medianAbsoluteError_train, gb_meanAbsoluteError_train, gb_RMSE_train, 'train'))
    gb_results_lst.append((k, gb_medianAbsoluteError_test, gb_meanAbsoluteError_test, gb_RMSE_test, 'test'))
# Out:
# n_estimators = 100 [TRAIN] >> median_abs_err = 0.628, mean_abs_err = 0.722, RMSE = 0.925
# n_estimators = 100 [TEST ] >> median_abs_err = 0.609, mean_abs_err = 0.771, RMSE = 1.016
# n_estimators = 200 [TRAIN] >> median_abs_err = 0.597, mean_abs_err = 0.692, RMSE = 0.886
# n_estimators = 200 [TEST ] >> median_abs_err = 0.598, mean_abs_err = 0.751, RMSE = 0.991
# n_estimators = 300 [TRAIN] >> median_abs_err = 0.577, mean_abs_err = 0.666, RMSE = 0.854
# n_estimators = 300 [TEST ] >> median_abs_err = 0.585, mean_abs_err = 0.734, RMSE = 0.971
# n_estimators = 400 [TRAIN] >> median_abs_err = 0.555, mean_abs_err = 0.643, RMSE = 0.826
# n_estimators = 400 [TEST ] >> median_abs_err = 0.552, mean_abs_err = 0.720, RMSE = 0.955
# n_estimators = 500 [TRAIN] >> median_abs_err = 0.535, mean_abs_err = 0.622, RMSE = 0.803
# n_estimators = 500 [TEST ] >> median_abs_err = 0.543, mean_abs_err = 0.708, RMSE = 0.943
# n_estimators = 600 [TRAIN] >> median_abs_err = 0.518, mean_abs_err = 0.606, RMSE = 0.783
# n_estimators = 600 [TEST ] >> median_abs_err = 0.533, mean_abs_err = 0.698, RMSE = 0.934
# n_estimators = 700 [TRAIN] >> median_abs_err = 0.503, mean_abs_err = 0.591, RMSE = 0.765
# n_estimators = 700 [TEST ] >> median_abs_err = 0.523, mean_abs_err = 0.689, RMSE = 0.926
# n_estimators = 800 [TRAIN] >> median_abs_err = 0.490, mean_abs_err = 0.577, RMSE = 0.749
# n_estimators = 800 [TEST ] >> median_abs_err = 0.525, mean_abs_err = 0.682, RMSE = 0.919
# n_estimators = 900 [TRAIN] >> median_abs_err = 0.477, mean_abs_err = 0.565, RMSE = 0.733
# n_estimators = 900 [TEST ] >> median_abs_err = 0.524, mean_abs_err = 0.675, RMSE = 0.914
# n_estimators = 1000 [TRAIN] >> median_abs_err = 0.460, mean_abs_err = 0.553, RMSE = 0.720
# n_estimators = 1000 [TEST ] >> median_abs_err = 0.520, mean_abs_err = 0.670, RMSE = 0.909
# n_estimators = 1100 [TRAIN] >> median_abs_err = 0.447, mean_abs_err = 0.542, RMSE = 0.707
# n_estimators = 1100 [TEST ] >> median_abs_err = 0.517, mean_abs_err = 0.665, RMSE = 0.905
# n_estimators = 1200 [TRAIN] >> median_abs_err = 0.437, mean_abs_err = 0.533, RMSE = 0.695
# n_estimators = 1200 [TEST ] >> median_abs_err = 0.515, mean_abs_err = 0.661, RMSE = 0.902
# n_estimators = 1300 [TRAIN] >> median_abs_err = 0.427, mean_abs_err = 0.524, RMSE = 0.685
# n_estimators = 1300 [TEST ] >> median_abs_err = 0.508, mean_abs_err = 0.658, RMSE = 0.900
# n_estimators = 1400 [TRAIN] >> median_abs_err = 0.416, mean_abs_err = 0.516, RMSE = 0.675
# n_estimators = 1400 [TEST ] >> median_abs_err = 0.497, mean_abs_err = 0.654, RMSE = 0.897
# n_estimators = 1500 [TRAIN] >> median_abs_err = 0.406, mean_abs_err = 0.508, RMSE = 0.666
# n_estimators = 1500 [TEST ] >> median_abs_err = 0.488, mean_abs_err = 0.652, RMSE = 0.895

# %%
gb_regression_results=pd.DataFrame(gb_results_lst,\
columns=['n_neighbors','median_abs_err','mean_abs_err','RMSE','dataset'])

# %%
plt.figure(figsize=(10, 5))
fig = sns.lineplot(data=gb_regression_results,x='n_neighbors',y='RMSE',hue='dataset')
fig.set_xticks(n_estimators);
fig.set_xticklabels(n_estimators);
fig.set_title('Change in RMSE in increasing Neighbors (GB Regressor)');
