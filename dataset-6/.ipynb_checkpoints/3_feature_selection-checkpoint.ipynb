# %% [markdown]
# ### Table of Contents:
# * [1. Feature selection and improve accuracy of data mining results ](#1)
# * &emsp;[1.1. Importing Libraries](#11)
# * &emsp;[1.2. Converting categorical data to numerical](#12)
# * &emsp;[1.3. Correlation Matrix](#13)
# * &emsp;[1.4. Heat-Map of correlation Matrix](#14)
# * &emsp;[1.5. Relevant attributes to improve the accuracy of data mining results](#15)

# %% [markdown]
# # 1. Feature selection and improve accuracy of data mining results <a class="anchor" id="1"></a>

# %% [markdown]
# Select relevant attributes from your dataset to improve the accuracy of data mining results.

# %% [markdown]
# ## 1.1. Importing Libraries <a class="anchor" id="11"></a>

# %%
import pandas as pd 
import numpy as np  
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.2. Converting categorical data to numerical <a class="anchor" id="12"></a>

# %%
df = pd.read_csv('data/training_data.csv')

# %%
categorical_features = ['company','rating','released','year',
                        'writer','adult','original_title','title','genres_edited',
                        'production_countries_edited','keywords_edited']
continuous_features = ['budget','score','votes']
normalized_features = [e+'_norm' for e in continuous_features]
target_features = ['isprofit','profitability_ratio']
all_features = categorical_features + continuous_features + normalized_features + target_features

# %%
df['company']=df['company'].astype('category').cat.codes
df['country']=df['country'].astype('category').cat.codes
#df['director']=df['director'].astype('category').cat.codes
df['genre']=df['genre'].astype('category').cat.codes
df['rating']=df['rating'].astype('category').cat.codes
df['star']=df['star'].astype('category').cat.codes
df['writer']=df['writer'].astype('category').cat.codes

# %% [markdown]
# ## 1.3. Correlation Matrix <a class="anchor" id="13"></a>

# %%
corr_df=df[all_features].corr()

# %%
corr_df
# Out:
#                       company   country     genre    rating      star  \
# company              1.000000 -0.023982 -0.068327 -0.096385  0.027815
# country             -0.023982  1.000000 -0.007972  0.025127 -0.038318
# genre               -0.068327 -0.007972  1.000000  0.146186  0.028526
# rating              -0.096385  0.025127  0.146186  1.000000  0.019548
# star                 0.027815 -0.038318  0.028526  0.019548  1.000000
# year                -0.025059 -0.056105  0.002205 -0.036979 -0.019621
# writer               0.022151 -0.021107  0.016050 -0.000902  0.020541
# budget               0.074765  0.061999 -0.289593 -0.179183  0.017721
# score               -0.011327 -0.095341  0.125387  0.095441  0.044390
# votes                0.005986  0.010459 -0.109605  0.051975  0.021660
# budget_norm          0.074765  0.061999 -0.289593 -0.179183  0.017721
# score_norm          -0.011327 -0.095341  0.125387  0.095441  0.044390
# votes_norm           0.005986  0.010459 -0.109605  0.051975  0.021660
# isprofit             0.019491  0.117668  0.033397 -0.087253 -0.010990
# profitability_ratio  0.021527  0.147908  0.052077 -0.104652 -0.010056
#
#                          year    writer    budget     score     votes  \
# company             -0.025059  0.022151  0.074765 -0.011327  0.005986
# country             -0.056105 -0.021107  0.061999 -0.095341  0.010459
# genre                0.002205  0.016050 -0.289593  0.125387 -0.109605
# rating              -0.036979 -0.000902 -0.179183  0.095441  0.051975
# star                -0.019621  0.020541  0.017721  0.044390  0.021660
# year                 1.000000 -0.024683  0.230331 -0.001962  0.307452
# writer              -0.024683  1.000000 -0.038455  0.036543 -0.002020
# budget               0.230331 -0.038455  1.000000 -0.096099  0.411472
# score               -0.001962  0.036543 -0.096099  1.000000  0.397032
# votes                0.307452 -0.002020  0.411472  0.397032  1.000000
# budget_norm          0.230331 -0.038455  1.000000 -0.096099  0.411472
# score_norm          -0.001962  0.036543 -0.096099  1.000000  0.397032
# votes_norm           0.307452 -0.002020  0.411472  0.397032  1.000000
# isprofit            -0.072287 -0.019914 -0.070816  0.117521  0.265030
# profitability_ratio -0.135231  0.003952 -0.120360  0.125577  0.254282
#
#                      budget_norm  score_norm  votes_norm  isprofit  \
# company                 0.074765   -0.011327    0.005986  0.019491
# country                 0.061999   -0.095341    0.010459  0.117668
# genre                  -0.289593    0.125387   -0.109605  0.033397
# rating                 -0.179183    0.095441    0.051975 -0.087253
# star                    0.017721    0.044390    0.021660 -0.010990
# year                    0.230331   -0.001962    0.307452 -0.072287
# writer                 -0.038455    0.036543   -0.002020 -0.019914
# budget                  1.000000   -0.096099    0.411472 -0.070816
# score                  -0.096099    1.000000    0.397032  0.117521
# votes                   0.411472    0.397032    1.000000  0.265030
# budget_norm             1.000000   -0.096099    0.411472 -0.070816
# score_norm             -0.096099    1.000000    0.397032  0.117521
# votes_norm              0.411472    0.397032    1.000000  0.265030
# isprofit               -0.070816    0.117521    0.265030  1.000000
# profitability_ratio    -0.120360    0.125577    0.254282  0.784049
#
#                      profitability_ratio
# company                         0.021527
# country                         0.147908
# genre                           0.052077
# rating                         -0.104652
# star                           -0.010056
# year                           -0.135231
# writer                          0.003952
# budget                         -0.120360
# score                           0.125577
# votes                           0.254282
# budget_norm                    -0.120360
# score_norm                      0.125577
# votes_norm                      0.254282
# isprofit                        0.784049
# profitability_ratio             1.000000

# %% [markdown]
# ## 1.4. Heat-Map of correlation Matrix <a class="anchor" id="14"></a>

# %%
plt.figure(figsize=(20,15))
sns.heatmap(corr_df,cmap='coolwarm',vmin=-1, vmax=1,annot=True,linewidth=.5);

# %% [markdown]
# ## 1.5. Relevant attributes to improve the accuracy of data mining results <a class="anchor" id="15"></a>

# %%
corr_df_features = set()
for i in range(len(corr_df.columns)-2):
    if corr_df.iloc[i,13]<-0.04 or corr_df.iloc[i,13]>0.04 or \
        corr_df.iloc[i,14]<-0.04 or corr_df.iloc[i,14]>0.04:
        corr_df_features.add(corr_df.columns[i])

# %%
corr_df_features
# Out:
# {'budget',
#  'budget_norm',
#  'country',
#  'genre',
#  'rating',
#  'score',
#  'score_norm',
#  'votes',
#  'votes_norm',
#  'year'}

# %%
df[list(corr_df_features)+['isprofit','profitability_ratio']].to_csv('data/final_training_data.csv')
